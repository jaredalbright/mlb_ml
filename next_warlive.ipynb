# %%
import os
import pandas as pd
import numpy as np
from pybaseball import batting_stats

# %%
START = 2002
END = 2023

# %%
if os.path.exists("batting.csv"):
    batting = pd.read_csv("batting.csv", index_col=0)
else:
    batting = batting_stats(START, END, qual=200)
    batting.to_csv("batting.csv")

# %%
working_batting = pd.read_csv('batting.csv')

# %%
working_batting = working_batting.groupby('IDfg', group_keys=False).filter(lambda x: x.shape[0] > 1)

# %%
working_batting
# Out:
#       Unnamed: 0   IDfg  Season          Name Team  Age    G   AB   PA    H  \
# 0              0   1109    2002   Barry Bonds  SFG   37  143  403  612  149
# 1              1   1109    2004   Barry Bonds  SFG   39  147  373  617  135
# 2              8  15640    2022   Aaron Judge  NYY   30  157  570  696  177
# 3              2   1109    2003   Barry Bonds  SFG   38  130  390  550  133
# 4             15  13611    2018  Mookie Betts  BOS   25  136  520  614  180
# ...          ...    ...     ...           ...  ...  ...  ...  ...  ...  ...
# 7471        7400   9272    2018   Chris Davis  BAL   32  128  470  522   79
# 7472        6861     45    2012   Rod Barajas  PIT   36  104  321  361   66
# 7473        7008    319    2011     Adam Dunn  CHW   31  122  415  496   66
# 7474        7344    620    2002   Neifi Perez  KCR   29  145  554  585  131
# 7475        1004   2113    2008   Ryan Doumit  PIT   27  116  431  465  137
#
#       ...  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  \
# 0     ...    NaN      NaN       NaN       0  0.127  0.191  NaN   NaN    NaN
# 1     ...    NaN      NaN       NaN       0  0.124  0.164  NaN   NaN    NaN
# 2     ...  118.4    246.0     0.609     404  0.169  0.287  NaN   NaN    NaN
# 3     ...    NaN      NaN       NaN       0  0.135  0.223  NaN   NaN    NaN
# 4     ...  110.6    217.0     0.500     434  0.220  0.270  NaN   NaN    NaN
# ...   ...    ...      ...       ...     ...    ...    ...  ...   ...    ...
# 7471  ...  111.8    113.0     0.401     282  0.174  0.316  NaN   NaN    NaN
# 7472  ...    NaN      0.0       NaN       0  0.147  0.258  NaN   NaN    NaN
# 7473  ...    NaN      0.0       NaN       0  0.169  0.295  NaN   NaN    NaN
# 7474  ...    NaN      NaN       NaN       0  0.130  0.187  NaN   NaN    NaN
# 7475  ...    NaN      0.0       NaN       0  0.144  0.231  NaN   NaN    NaN
#
#       L-WAR
# 0      12.7
# 1      11.9
# 2      11.6
# 3      10.2
# 4      10.4
# ...     ...
# 7471   -2.6
# 7472   -2.6
# 7473   -2.9
# 7474   -2.9
# 7475   -3.1
#
# [7092 rows x 321 columns]

# %%
def next_season(player):
    player = player.sort_values("Season")
    player['Next_WAR'] = player['WAR'].shift(-1)
    return player

working_batting = working_batting.groupby("IDfg", group_keys=False).apply(next_season, include_groups=True)
# Out:
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\3321812112.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   working_batting = working_batting.groupby("IDfg", group_keys=False).apply(next_season, include_groups=True)

# %%
working_batting[['IDfg', 'Name', 'Season', 'WAR', 'Next_WAR']]
# Out:
#        IDfg                Name  Season  WAR  Next_WAR
# 4144      1     Alfredo Amezaga    2006  1.1       2.0
# 2739      1     Alfredo Amezaga    2007  2.0       1.2
# 3975      1     Alfredo Amezaga    2008  1.2       NaN
# 1072      2     Garret Anderson    2002  3.7       5.1
# 439       2     Garret Anderson    2003  5.1       0.8
# ...     ...                 ...     ...  ...       ...
# 771   27506        Ha-seong Kim    2023  4.3       NaN
# 3559  27676  Vinnie Pasquantino    2022  1.4       0.1
# 5903  27676  Vinnie Pasquantino    2023  0.1       NaN
# 2974  30116        Seiya Suzuki    2022  1.8       3.0
# 1580  30116        Seiya Suzuki    2023  3.0       NaN
#
# [7092 rows x 5 columns]

# %%
null_count = working_batting.isnull().sum()

# %%
null_count
# Out:
# Unnamed: 0       0
# IDfg             0
# Season           0
# Name             0
# Team             0
#               ...
# xBA           7092
# xSLG          7092
# xwOBA         7092
# L-WAR            0
# Next_WAR      1235
# Length: 322, dtype: int64

# %%
complete_cols = list(working_batting.columns[null_count == 0])

# %%
working_batting = working_batting[complete_cols + ['Next_WAR']].copy()

# %%
working_batting.dtypes[working_batting.dtypes == "object"]
# Out:
# Name       object
# Team       object
# Dol        object
# Age Rng    object
# dtype: object

# %%
del working_batting['Dol']
del working_batting['Age Rng']

# %%
working_batting['team_code'] = working_batting['Team'].astype('category').cat.codes

# %%
batting_full = working_batting.copy()
working_batting = working_batting.dropna()

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = Ridge(alpha=1)

split = TimeSeriesSplit(n_splits = 3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=20, direction='forward', cv=split, n_jobs=4)

# %%
removed_columns = ['Next_WAR', 'Name', 'Team', 'IDfg', 'Season']
selected_columns = working_batting.columns[~working_batting.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# Out:
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.77966555 0.70086957 0.16053512 ... 0.61458194 0.1522408  0.39411371]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.34615385 0.38461538 0.42307692 ... 0.26923077 0.19230769 0.30769231]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.73504274 0.74358974 0.95726496 ... 0.88888889 0.22222222 0.55555556]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31294964 0.43165468 0.85971223 ... 0.64208633 0.17625899 0.42625899]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.30795848 0.42906574 0.82698962 ... 0.66089965 0.16955017 0.42560554]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.24568966 0.32327586 0.7112069  ... 0.43103448 0.19827586 0.31896552]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.27830189 0.31603774 0.44339623 ... 0.3490566  0.20283019 0.25      ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.15517241 0.24137931 0.96551724 ... 0.5        0.17241379 0.37931034]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.13043478 0.39130435 0.13043478 ... 0.13043478 0.         0.08695652]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.0483871  0.03225806 0.46774194 ... 0.17741935 0.16129032 0.22580645]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.2406015  0.27067669 0.62406015 ... 0.36090226 0.11278195 0.33082707]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08053691 0.15436242 0.77852349 ... 0.34899329 0.12751678 0.26174497]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.13478261 0.14347826 0.12173913 ... 0.21304348 0.14347826 0.17391304]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.03333333 0.         0.09166667 ... 0.         0.00833333 0.025     ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.17674419 0.20465116 0.33488372 ... 0.42790698 0.12093023 0.4744186 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.09677419 0.12903226 0.         ... 0.22580645 0.09677419 0.12903226]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.0625 0.3125 0.625  ... 0.25   0.125  0.1875]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.29166667 0.16666667 0.         ... 0.125      0.         0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.15625 0.125   0.34375 ... 0.28125 0.15625 0.25   ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.25641026 0.16666667 0.07692308 ... 0.15384615 0.01282051 0.11538462]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.5        0.29166667 0.16666667 ... 0.08333333 0.         0.20833333]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.30107527 0.34677419 0.48924731 ... 0.36827957 0.16935484 0.23387097]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.27340824 0.34831461 0.75655431 ... 0.5505618  0.26966292 0.3670412 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.2260274  0.38356164 0.83561644 ... 0.51369863 0.19863014 0.30136986]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.2        0.2        0.23076923 ... 0.36923077 0.07692308 0.15384615]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31749049 0.41064639 0.58174905 ... 0.67148289 0.16958175 0.4878327 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.25358852 0.33971292 0.42902711 ... 0.53110048 0.16108453 0.41467305]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.34420772 0.43541944 0.66045273 ... 0.73235686 0.16245007 0.50798935]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.28070175 0.19298246 0.15789474 ... 0.28070175 0.07017544 0.26315789]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.19101124 0.20224719 0.01123596 ... 0.04494382 0.01123596 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.10526316 0.21052632 0.02631579 ... 0.02631579 0.02631579 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.19892473 0.24731183 0.55376344 ... 0.37096774 0.25806452 0.32795699]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.30452675 0.32098765 0.50205761 ... 0.43209877 0.55555556 0.47325103]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31325301 0.31325301 0.01204819 ... 0.03614458 0.         0.06024096]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.42553191 0.42553191 0.63829787 ... 0.5        0.69148936 0.55319149]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.21287129 0.18811881 0.10148515 ... 0.23019802 0.33663366 0.25      ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.28787879 0.27272727 0.28282828 ... 0.2979798  0.17171717 0.46464646]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.34920635 0.33333333 0.37301587 ... 0.3968254  0.56349206 0.42857143]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.17985612 0.23021583 0.55395683 ... 0.33093525 0.4676259  0.42446043]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08333333 0.1468254  0.49206349 ... 0.25396825 0.32936508 0.35714286]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.44827586 0.43678161 0.54022989 ... 0.48275862 0.55172414 0.62068966]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.60330579 0.54545455 0.36363636 ... 0.39669421 0.42975207 0.40495868]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.39310345 0.37241379 0.52413793 ... 0.52413793 0.52413793 0.53793103]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08287293 0.04972376 0.33977901 ... 0.15745856 0.27900552 0.28176796]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.36206897 0.4137931  0.63793103 ... 0.60344828 0.52586207 0.28448276]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.53932584 0.47191011 0.35955056 ... 0.50561798 0.50561798 0.51685393]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.5037594  0.4962406  0.2556391  ... 0.18796992 0.30827068 0.63157895]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.66292135 0.47191011 0.2247191  ... 0.51685393 0.30337079 0.45505618]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.65217391 0.71014493 0.47826087 ... 0.52173913 0.42028986 0.44927536]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.21088435 0.29251701 0.65986395 ... 0.39455782 0.61904762 0.50340136]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.         0.         0.         ... 0.70784641 0.37729549 0.48414023]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\2574327989.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.35294118 0.35294118 0.02941176 ... 0.76470588 0.41176471 0.17647059]' has dtype incompatible with int8, please explicitly cast to a compatible dtype first.
#   working_batting.loc[:, selected_columns] = scaler.fit_transform(working_batting[selected_columns])

# %%
sfs.fit(working_batting[selected_columns], working_batting['Next_WAR'])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=Ridge(alpha=1), n_features_to_select=20,
#                           n_jobs=4)

# %%
batting_backup = working_batting.copy()

# %%
batting_backup
# Out:
#       Unnamed: 0   IDfg  Season                Name Team       Age         G  \
# 4144    0.779666      1    2006     Alfredo Amezaga  FLA  0.346154  0.735043
# 2739    0.700870      1    2007     Alfredo Amezaga  FLA  0.384615  0.743590
# 1072    0.160535      2    2002     Garret Anderson  ANA  0.423077  0.957265
# 439     0.117993      2    2003     Garret Anderson  ANA  0.461538  0.965812
# 4588    0.358796      2    2004     Garret Anderson  ANA  0.500000  0.564103
# ...          ...    ...     ...                 ...  ...       ...       ...
# 7176    0.920134  27465    2022   Spencer Torkelson  DET  0.115385  0.547009
# 5510    0.930033  27506    2021        Ha-seong Kim  SDP  0.230769  0.606838
# 1120    0.614582  27506    2022        Ha-seong Kim  SDP  0.269231  0.888889
# 3559    0.152241  27676    2022  Vinnie Pasquantino  KCR  0.192308  0.222222
# 2974    0.394114  30116    2022        Seiya Suzuki  CHC  0.307692  0.555556
#
#             AB        PA         H  ...    Oppo%+    Soft%+     Med%+  \
# 4144  0.312950  0.307958  0.245690  ...  0.503759  0.662921  0.652174
# 2739  0.431655  0.429066  0.323276  ...  0.496241  0.471910  0.710145
# 1072  0.859712  0.826990  0.711207  ...  0.255639  0.224719  0.478261
# 439   0.859712  0.818339  0.737069  ...  0.255639  0.365169  0.507246
# 4588  0.507194  0.475779  0.443966  ...  0.218045  0.297753  0.608696
# ...        ...       ...       ...  ...       ...       ...       ...
# 7176  0.359712  0.352941  0.185345  ...  0.436090  0.337079  0.550725
# 5510  0.192446  0.169550  0.103448  ...  0.097744  0.629213  0.463768
# 1120  0.642086  0.660900  0.431034  ...  0.187970  0.516854  0.521739
# 3559  0.176259  0.169550  0.198276  ...  0.308271  0.303371  0.420290
# 2974  0.426259  0.425606  0.318966  ...  0.631579  0.455056  0.449275
#
#         Hard%+    Events     CStr%      CSW%     L-WAR  Next_WAR  team_code
# 4144  0.210884  0.000000  0.582979  0.524229  0.265823       2.0   0.352941
# 2739  0.292517  0.000000  0.527660  0.396476  0.322785       1.2   0.352941
# 1072  0.659864  0.000000  0.365957  0.418502  0.430380       5.1   0.029412
# 439   0.523810  0.000000  0.480851  0.506608  0.518987       0.8   0.029412
# 4588  0.448980  0.000000  0.531915  0.585903  0.246835      -0.2   0.029412
# ...        ...       ...       ...       ...       ...       ...        ...
# 7176  0.496599  0.439065  0.506383  0.607930  0.132911       1.3   0.323529
# 5510  0.380952  0.335559  0.702128  0.731278  0.227848       3.7   0.764706
# 1120  0.394558  0.707846  0.655319  0.612335  0.430380       4.3   0.764706
# 3559  0.619048  0.377295  0.472340  0.400881  0.291139       0.1   0.411765
# 2974  0.503401  0.484140  0.770213  0.770925  0.329114       3.0   0.176471
#
# [5857 rows x 133 columns]

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
def backtest(data, model, predictors, start=5, step=1):
    all_predictions = []

    years = sorted(data['Season'].unique())

    for i in range(start, len(years), step):
        current_year = years[i]

        train = data[data['Season'] < current_year]
        test = data[data['Season'] == current_year]

        model.fit(train[predictors], train['Next_WAR'])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index = test.index)
        combined = pd.concat([test["Next_WAR"], preds], axis = 1)
        combined.columns = ['actual', 'predictions']

        all_predictions.append(combined)

    return pd.concat(all_predictions)

# %%
predictions = backtest(working_batting, rr, predictors)

# %%
predictions
# Out:
#       actual  predictions
# 2739     1.2     1.384595
# 3564     1.4     0.738473
# 4810    -0.1     0.515400
# 4898     0.6     0.983679
# 1841     4.8     2.256597
# ...      ...          ...
# 6360     0.0     1.714227
# 7176     1.3     1.652519
# 1120     4.3     2.789176
# 3559     0.1     2.078297
# 2974     3.0     2.076533
#
# [4409 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(predictions['actual'], predictions['predictions'])
# Out:
# 2.6787306746900406

# %%
working_batting['Next_WAR'].describe()
# Out:
# count    5857.000000
# mean        1.791668
# std         1.976187
# min        -3.100000
# 25%         0.400000
# 50%         1.500000
# 75%         2.900000
# max        11.900000
# Name: Next_WAR, dtype: float64

# %%
2.693236744398038 ** .5
# Out:
# 1.641108388985334

# %%
working_batting = working_batting.copy()

# %%
def player_history(df):
    df = df.sort_values("Season")

    df['player_season'] = range(0, df.shape[0])
    df['war_corr'] = list(df[['player_season', 'WAR']].expanding().corr().loc[(slice(None), 'player_season'), 'WAR'])
    df['war_corr'].fillna(1, inplace=True)

    df['war_diff'] = df['WAR'] / df['WAR'].shift(1)
    df['war_diff'].fillna(1, inplace=True)

    df['war_diff'][df['war_diff'] == np.inf] = 1

    return df

working_batting = working_batting.groupby("IDfg", group_keys=False).apply(player_history, include_groups=True)
# Out:
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_corr'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['war_diff'].fillna(1, inplace=True)
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['war_diff'][df['war_diff'] == np.inf] = 1
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\1727317652.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   working_batting = working_batting.groupby("IDfg", group_keys=False).apply(player_history, include_groups=True)

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
def group_averages(df):
    return df['WAR'] / df['WAR'].mean()

# %%
working_batting['war_season'] = batting.groupby('Season', group_keys=False).apply(group_averages)
# Out:
# C:\Users\albri\AppData\Local\Temp\ipykernel_16864\31885854.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   working_batting['war_season'] = batting.groupby('Season', group_keys=False).apply(group_averages)

# %%
new_predictors = predictors + ['player_season', 'war_corr', 'war_season', 'war_diff']

# %%
predictions = backtest(working_batting, rr, new_predictors)

# %%
mean_squared_error(predictions['actual'], predictions['predictions'])
# Out:
# 2.6588928003409205

# %%
pd.Series(rr.coef_, index=new_predictors).sort_values()
# Out:
# Age             -2.758980
# BABIP           -1.647857
# G               -1.547315
# SO              -1.350573
# BU              -1.152043
# Soft%           -0.953515
# ISO             -0.634823
# CH%             -0.387220
# war_diff        -0.266007
# CB%             -0.250442
# war_corr        -0.141254
# player_season    0.000073
# war_season       0.035900
# PH               0.077532
# OBP+             0.394698
# Unnamed: 0       0.561338
# Oppo%+           0.620277
# Spd              0.812610
# SB               0.867284
# Balls            0.928048
# Strikes          1.498028
# IBB              1.935834
# Hard%+           2.499669
# WAR              7.418849
# dtype: float64

# %%
diff = predictions['actual'] - predictions['predictions']

# %%
merged = predictions.merge(working_batting, left_index=True, right_index=True)

# %%
merged['diff'] = (predictions['actual'] - predictions['predictions']).abs()

# %%
merged[['IDfg', 'Season', 'Name', 'WAR', 'Next_WAR', 'diff']].sort_values(['diff'])
# Out:
#        IDfg  Season               Name       WAR  Next_WAR      diff
# 6924  14109    2019  Albert Almora Jr.  0.158228       0.6  0.000251
# 7063   4314    2022         Joey Votto  0.145570       0.1  0.000439
# 5141   9393    2017         Matt Adams  0.227848       0.5  0.000796
# 1202   7287    2011    Carlos Gonzalez  0.417722       2.7  0.001039
# 364     791    2011   Brandon Phillips  0.537975       3.3  0.001198
# ...     ...     ...                ...       ...       ...       ...
# 3780   1875    2009      Josh Hamilton  0.278481       8.4  6.555312
# 6048   5631    2010          Matt Kemp  0.196203       8.3  6.568964
# 948    9166    2010       Buster Posey  0.443038       9.8  6.661731
# 328   15640    2021        Aaron Judge  0.544304      11.2  7.297012
# 3284  11579    2014       Bryce Harper  0.297468       9.3  7.632589
#
# [4409 rows x 6 columns]
